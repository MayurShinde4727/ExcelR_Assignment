# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from numpy import reshape
import statsmodels.formula.api as smf

# %% [markdown]
# # Question 1

# %%
data = pd.read_csv('delivery_time.csv')
data.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
X = np.array(data.iloc[:,0])
X= X.reshape(-1,1)
X
# Out:
# array([[21.  ],
#        [13.5 ],
#        [19.75],
#        [24.  ],
#        [29.  ],
#        [15.35],
#        [19.  ],
#        [ 9.5 ],
#        [17.9 ],
#        [18.75],
#        [19.83],
#        [10.75],
#        [16.68],
#        [11.5 ],
#        [12.03],
#        [14.88],
#        [13.75],
#        [18.11],
#        [ 8.  ],
#        [17.83],
#        [21.5 ]])

# %%
Y = np.array(data.iloc[:,1])
Y = Y.reshape(-1,1)
Y
# Out:
# array([[10],
#        [ 4],
#        [ 6],
#        [ 9],
#        [10],
#        [ 6],
#        [ 7],
#        [ 3],
#        [10],
#        [ 9],
#        [ 8],
#        [ 4],
#        [ 7],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 6],
#        [ 7],
#        [ 2],
#        [ 7],
#        [ 5]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
plt.scatter(data['Delivery Time'],y=data['Sorting Time'])
plt.xlabel('Delivery Time')
plt.ylabel('Sorting Time')
plt.show()

# %%
sns.regplot(x=data['Delivery Time'],y=data['Sorting Time'])

# %%
sns.boxplot(x=data['Delivery Time'])

# %%
sns.boxplot(x=data['Sorting Time'])

# %%
sns.distplot(data['Delivery Time'],bins=3,color='Green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Sorting Time'],bins=3,color='Red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
new = pd.DataFrame({'detime':[10,20,34,23,41]})
new
# Out:
#    detime
# 0      10
# 1      20
# 2      34
# 3      23
# 4      41

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
model.predict(new)
# Out:
# array([[ 3.38076291],
#        [ 7.51819919],
#        [13.31060999],
#        [ 8.75943008],
#        [16.20681538]])

# %%
model.predict(Y)
# Out:
# array([[3.38076291],
#        [0.89830115],
#        [1.7257884 ],
#        [2.96701929],
#        [3.38076291],
#        [1.7257884 ],
#        [2.13953203],
#        [0.48455752],
#        [3.38076291],
#        [2.96701929],
#        [2.55327566],
#        [0.89830115],
#        [2.13953203],
#        [0.48455752],
#        [0.48455752],
#        [0.89830115],
#        [1.7257884 ],
#        [2.13953203],
#        [0.07081389],
#        [2.13953203],
#        [1.31204477]])

# %%
data['Predicted'] = Y

# %%
data
# Out:
#     Delivery Time  Sorting Time  Predicted
# 0           21.00            10         10
# 1           13.50             4          4
# 2           19.75             6          6
# 3           24.00             9          9
# 4           29.00            10         10
# 5           15.35             6          6
# 6           19.00             7          7
# 7            9.50             3          3
# 8           17.90            10         10
# 9           18.75             9          9
# 10          19.83             8          8
# 11          10.75             4          4
# 12          16.68             7          7
# 13          11.50             3          3
# 14          12.03             3          3
# 15          14.88             4          4
# 16          13.75             6          6
# 17          18.11             7          7
# 18           8.00             2          2
# 19          17.83             7          7
# 20          21.50             5          5

# %% [markdown]
# # Question 2

# %%
data1 = pd.read_csv('Salary_Data.csv')
data1
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data1.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
plt.scatter(x=data1['YearsExperience'],y=data1.Salary)
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
sns.distplot(data1['YearsExperience'],bins=4,color='Blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data1['Salary'],bins=4,color='Orange')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data1.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
model1 = smf.ols('Salary~YearsExperience',data=data1).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Wed, 15 Sep 2021   Prob (F-statistic):           1.14e-20
# Time:                        15:19:14   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model1.pvalues,model1.rsquared
# Out:
# (Intercept          5.511950e-12
#  YearsExperience    1.143068e-20
#  dtype: float64, 0.9569566641435086)

# %%
pred_data = pd.DataFrame(data=new1,columns=['YearsExperience'])
pred_data
# Out:
#    YearsExperience
# 0               30
# 1               31
# 2               32
# 3               33
# 4               34
# 5               35

# %%
model1.predict(pred_data)
# Out:
# 0    309291.069842
# 1    318741.032164
# 2    328190.994485
# 3    337640.956807
# 4    347090.919128
# 5    356540.881450
# dtype: float64

# %%
y = np.round(model1.predict(data1),0)
y
# Out:
# 0      36187.0
# 1      38077.0
# 2      39967.0
# 3      44692.0
# 4      46582.0
# 5      53197.0
# 6      54142.0
# 7      56032.0
# 8      56032.0
# 9      60757.0
# 10     62647.0
# 11     63592.0
# 12     63592.0
# 13     64537.0
# 14     68317.0
# 15     72097.0
# 16     73987.0
# 17     75877.0
# 18     81547.0
# 19     82492.0
# 20     90052.0
# 21     92887.0
# 22    100447.0
# 23    103282.0
# 24    108007.0
# 25    110842.0
# 26    115567.0
# 27    116512.0
# 28    123127.0
# 29    125017.0
# dtype: float64

# %%
data1['Predicted'] = y

# %%
data1
# Out:
#     YearsExperience    Salary  Predicted
# 0               1.1   39343.0    36187.0
# 1               1.3   46205.0    38077.0
# 2               1.5   37731.0    39967.0
# 3               2.0   43525.0    44692.0
# 4               2.2   39891.0    46582.0
# 5               2.9   56642.0    53197.0
# 6               3.0   60150.0    54142.0
# 7               3.2   54445.0    56032.0
# 8               3.2   64445.0    56032.0
# 9               3.7   57189.0    60757.0
# 10              3.9   63218.0    62647.0
# 11              4.0   55794.0    63592.0
# 12              4.0   56957.0    63592.0
# 13              4.1   57081.0    64537.0
# 14              4.5   61111.0    68317.0
# 15              4.9   67938.0    72097.0
# 16              5.1   66029.0    73987.0
# 17              5.3   83088.0    75877.0
# 18              5.9   81363.0    81547.0
# 19              6.0   93940.0    82492.0
# 20              6.8   91738.0    90052.0
# 21              7.1   98273.0    92887.0
# ...
